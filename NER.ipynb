# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Alex Andino Yuquilema
#
# Fecha: 29-04-2024
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Named-Entity Recognition</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno se familiarice con el manejo de la librería spacy, así como con los conceptos básicos de manejo de las técnicas NER
#
# **Descripción**
#
# En esta actividad debes procesar de forma automática un texto en lenguaje natural para detectar características básicas en el mismo, y para identificar y etiquetar las ocurrencias de conceptos como localización, moneda, empresas, etc.
#
# En la primera parte del ejercicio se proporciona un código fuente a través del cual se lee un archivo de texto y se realiza un preprocesado del mismo. En esta parte el alumno tan sólo debe ejecutar y entender el código proporcionado.
#
# En la segunda parte del ejercicio se plantean una serie de preguntas que deben ser respondidas por el alumno. Cada pregunta deberá responderse con un fragmento de código fuente que esté acompañado de la explicación correspondiente. Para elaborar el código solicitado, el alumno deberá visitar la documentación de la librería spacy, cuyos enlaces se proporcionarán donde corresponda.

# %% [markdown]
# # Parte 1: carga y preprocesamiento del texto a analizar

# %% [markdown]
# Observa las diferentes librerías que se están importando.

# %%
import pathlib
import spacy
from spacy import displacy
import en_core_web_sm

# %% [markdown]
# El siguiente código simplemente carga y preprocesa el texto. Para ello, lo primero que hace es cargar un modelo de lenguaje previamente entrenado. En este caso, se utiliza <i>en_core_web_sm</i>:
#
# https://spacy.io/models/en#en_core_web_sm
#
# Al cargar el modelo de lenguaje se genera un <i>Pipeline</i>, que nos permite realizar las diferentes tareas. En este caso, vamos a utilizar el pipeline para hacer un preprocesamiento básico, que consiste en tokenizar el texto.
#
# Al final del código proporcionado <i>doc</i> representa una versión tokenizada del texto leído.

# %%
#Cargar el modelo, en conjunto con el <i>input</i>
nlp = en_core_web_sm.load()
file_name = "barack-obama-speech.txt"
doc = nlp(pathlib.Path(file_name).read_text(encoding="utf-8"))

# %% [markdown]
# ### Playground
#
# La variable <i>doc</i> es un objeto de la clase <i>Doc</i> (https://spacy.io/api/doc)
#
# Visita la documentación de dicha clase y experimenta probando las diferentes funciones y atributos

# %%
# Puedes insertar aquí código de pruebas para experimentar con las diferentes funciones y atributos de 'doc'.
print("interar tokens para acceder a cada uno de ellos")
print([t.text for t in doc])

print("Numero de tokens en el documento")
print(len(doc))

print("Validar si una palabra existe en la entrada, no cuenta la cantidad o frecuencia")
print(doc.has_extension("election"))

print("Cuenta la frecuencia de las palabras de una entrada")
from spacy.attrs import ORTH
print(doc.count_by(ORTH))

print("Entidades en la entrada")
ents = list(doc.ents)
print(ents) #para llamar al nombre de la entidad ents.label_ y ents.text para el valor

print("puntuacion de la categoria mapeada de texto con span")
print(doc.cats)

print("oraciones presentes en el documento")
sents = list(doc.sents)
print(len(sents))
print(doc.vector_norm)
print(doc.vector.dtype)
# Out:
# interar tokens para acceder a cada uno de ellos
# ['“', 'Hello', ',', 'Chicago', '.', '\n', 'If', 'there', 'is', 'anyone', 'out', 'there', 'who', 'still', 'doubts', 'that', 'America', 'is', 'a', 'place', 'where', 'all', 'things', 'are', 'possible', ',', 'who', 'still', 'wonders', 'if', 'the', 'dream', 'of', 'our', 'founders', 'is', 'alive', 'in', 'our', 'time', ',', 'who', 'still', 'questions', 'the', 'power', 'of', 'our', 'democracy', ',', 'tonight', 'is', 'your', 'answer', '.', '\n', 'It', '’s', 'the', 'answer', 'told', 'by', 'lines', 'that', 'stretched', 'around', 'schools', 'and', 'churches', 'in', 'numbers', 'this', 'nation', 'has', 'never', 'seen', ',', 'by', 'people', 'who', 'waited', 'three', 'hours', 'and', 'four', 'hours', ',', 'many', 'for', 'the', 'first', 'time', 'in', 'their', 'lives', ',', 'because', 'they', 'believed', 'that', 'this', 'time', 'must', 'be', 'different', ',', 'that', 'their', 'voices', 'could', 'be', 'that', 'difference', '.', '\n', 'It', '’s', 'the', 'answer', 'spoken', 'by', 'young', 'and', 'old', ',', 'rich', 'and', 'poor', ',', 'Democrat', 'and', 'Republican', ',', 'black', ',', 'white', ',', 'Hispanic', ',', 'Asian', ',', 'Native', 'American', ',', 'gay', ',', 'straight', ',', 'disabled', 'and', 'not', 'disabled', '.', 'Americans', 'who', 'sent', 'a', 'message', 'to', 'the', 'world', 'that', 'we', 'have', 'never', 'been', 'just', 'a', 'collection', 'of', 'individuals', 'or', 'a', 'collection', 'of', 'red', 'states', 'and', 'blue', 'states', '.', '\n', 'We', 'are', ',', 'and', 'always', 'will', 'be', ',', 'the', 'United', 'States', 'of', 'America', '.', '\n', 'It', '’s', 'the', 'answer', 'that', 'led', 'those', 'who', '’ve', 'been', 'told', 'for', 'so', 'long', 'by', 'so', 'many', 'to', 'be', 'cynical', 'and', 'fearful', 'and', 'doubtful', 'about', 'what', 'we', 'can', 'achieve', 'to', 'put', 'their', 'hands', 'on', 'the', 'arc', 'of', 'history', 'and', 'bend', 'it', 'once', 'more', 'toward', 'the', 'hope', 'of', 'a', 'better', 'day', '.', '\n', 'It', '’s', 'been', 'a', 'long', 'time', 'coming', ',', 'but', 'tonight', ',', 'because', 'of', 'what', 'we', 'did', 'on', 'this', 'date', 'in', 'this', 'election', 'at', 'this', 'defining', 'moment', 'change', 'has', 'come', 'to', 'America', '.', '\n', '[', 'read', 'more', ']', '\n\n', 'We', 'did', 'n’t', 'start', 'with', 'much', 'money', 'or', 'many', 'endorsements', '.', 'Our', 'campaign', 'was', 'not', 'hatched', 'in', 'the', 'halls', 'of', 'Washington', '.', 'It', 'began', 'in', 'the', 'backyards', 'of', 'Des', 'Moines', 'and', 'the', 'living', 'rooms', 'of', 'Concord', 'and', 'the', 'front', 'porches', 'of', 'Charleston', '.', 'It', 'was', 'built', 'by', 'working', 'men', 'and', 'women', 'who', 'dug', 'into', 'what', 'little', 'savings', 'they', 'had', 'to', 'give', '$', '5', 'and', '$', '10', 'and', '$', '20', 'to', 'the', 'cause', '.', '\n', 'It', 'grew', 'strength', 'from', 'the', 'young', 'people', 'who', 'rejected', 'the', 'myth', 'of', 'their', 'generation', '’s', 'apathy', 'who', 'left', 'their', 'homes', 'and', 'their', 'families', 'for', 'jobs', 'that', 'offered', 'little', 'pay', 'and', 'less', 'sleep', '.', '\n', 'It', 'drew', 'strength', 'from', 'the', 'not', '-', 'so', '-', 'young', 'people', 'who', 'braved', 'the', 'bitter', 'cold', 'and', 'scorching', 'heat', 'to', 'knock', 'on', 'doors', 'of', 'perfect', 'strangers', ',', 'and', 'from', 'the', 'millions', 'of', 'Americans', 'who', 'volunteered', 'and', 'organized', 'and', 'proved', 'that', 'more', 'than', 'two', 'centuries', 'later', 'a', 'government', 'of', 'the', 'people', ',', 'by', 'the', 'people', ',', 'and', 'for', 'the', 'people', 'has', 'not', 'perished', 'from', 'the', 'Earth', '.', '\n', 'This', 'is', 'your', 'victory', '.', '\n', 'And', 'I', 'know', 'you', 'did', 'n’t', 'do', 'this', 'just', 'to', 'win', 'an', 'election', '.', 'And', 'I', 'know', 'you', 'did', 'n’t', 'do', 'it', 'for', 'me', '.', '\n', 'You', 'did', 'it', 'because', 'you', 'understand', 'the', 'enormity', 'of', 'the', 'task', 'that', 'lies', 'ahead',  ...
# Numero de tokens en el documento
# 1939
# Validar si una palabra existe en la entrada, no cuenta la cantidad o frecuencia
# False
# Cuenta la frecuencia de las palabras de una entrada
# {16073121960489476521: 2, 15777305708150031551: 1, 2593208677638477497: 93, 3767271857074311788: 1, 12646065887601541794: 80, 962983613142996970: 45, 9698320431655714481: 1, 2112642640949226496: 11, 3411606890003347522: 14, 444920330522528470: 1, 1696981056005371314: 3, 3876862883474502309: 23, 5937879255812462177: 4, 13627633532852943614: 2, 4380130941430378203: 35, 13134984502707718284: 12, 11901859001352538922: 38, 7512738811199700769: 1, 16318918034475841628: 3, 13409319323822384369: 6, 3586418546468265269: 2, 5012629990875267006: 12, 1322442146463163273: 1, 8805335442967430160: 1, 12446819118446800910: 6, 7425985699627899538: 81, 15068273739048504437: 2, 886050111519832510: 48, 17577015140245084783: 22, 16713696713169059598: 1, 1853724879316918694: 1, 3002984154512732771: 28, 8885804376230376864: 7, 3626233646565002230: 1, 10405720708504167118: 2, 9159172889970741801: 3, 8140828781860861265: 11, 1572612192562026184: 6, 10726089026535385654: 5, 7859011591137717335: 10, 614914527630368944: 18, 1245643389253732868: 5, 16764210730586636600: 10, 9199143519903352027: 1, 14177977645724836190: 1, 3194226484742107227: 2, 4067498641991372780: 2, 2283656566040971221: 60, 8083007201880587374: 1, 16181666555170135050: 1, 1995909169258310477: 14, 4877621044794520897: 6, 1248239241591158246: 5, 10879546028211794123: 3, 15866718007544400459: 3, 7593739049417968140: 12, 938849898741779964: 1, 8241648526530492509: 1, 8902621109934631094: 3, 13283271314760746512: 1, 9720044723474553187: 7, 16037325823156266367: 17, 11860158879560853892: 2, 4244585616942201722: 11, 11245784847398743405: 2, 16950148841647037698: 6, 16875582379069451158: 4, 16611054741588718914: 1, 7290638946010101875: 3, 10382539506755952630: 13, 17379251038783395147: 1, 9869113163941486217: 3, 7494117911267222209: 2, 8716931238876204650: 1, 272519388878402132: 1, 5946595046901399946: 3, 2483095116303079762: 2, 10580761479554314246: 1, 13558078257114079636: 1, 15238488866377567561: 1, 12912724278213475795: 2, 6088217638129078516: 1, 16857069738040043275: 1, 17903303639173240179: 1, 1900673716595431757: 1, 8944222823890243730: 1, 8947108287989031391: 4, 5754201015754630361: 1, 15258408712064592081: 1, 16380637432796080760: 2, 447765159362469301: 14, 11011508796349597242: 4, 16056986141218963985: 1, 1381057396011922202: 1, 3791531372978436496: 42, 1703489418272052182: 5, 16064069575701507746: 39, 14692702688101715474: 11, 12517269084653561647: 5, 7148522813498185515: 3, 9613535637429559193: 2, 3577020009142861760: 1, 3740602843040177340: 9, 17551718516836219974: 1, 3554169177543738620: 2, 15764874044283507388: 1, 15667417291854480293: 7, 17471638809377599778: 2, 18307573501153647118: 17, 13226800834791099135: 1, 3278625293875499398: 1, 5121906190925376702: 1, 5224941539530611462: 9, 14018295222045480654: 2, 9781598966686434415: 9, 12965068231793614765: 5, 15884664789999019803: 1, 736430059246765513: 1, 2022212890482364868: 1, 942632335873952620: 4, 5865838185239622912: 5, 6635067063807956629: 15, 1478592441673796122: 2, 11532405253426108718: 2, 1689680727489136653: 1, 5640369432778651323: 11, 12368696851754995130: 1, 6249630248276940353: 1, 13789415009900341908: 1, 10239237003504588839: 7, 18381768081115421630: 2, 2160362229054775535: 7, 9664647946711101580: 1, 4429974322456332988: 5, 13468287115010965206: 1, 1608482186128794349: 1, 17483048438088526599: 1, 14560795576765492085: 6, 13583488448875926965: 5, 15387552459474943870: 1, 9665076245915730897: 5, 11667289587015813222: 2, 16403209304200829953: 1, 12670099585788978990: 2, 3979101002134440957: 6, 5307304325359566725: 2, 4398759943034541363: 2, 11792590063656742891: 1, 3806482680584466996: 1, 908432558851201422: 1, 16712971838599463365: 9, 6480458294193393462: 1, 12510949447758279278: 8, 1935074700818135162: 3, 14917444839815175757: 1, 12088961362747858741: 1, 10852253267983130536: 3, 3724113568749218963: 1, 9921686513378912864: 10, 9062216858165681875: 1, 12040686606081341363: 1, 8812112232444892211: 1, 1094525555515193507 ...
# Entidades en la entrada
# [Chicago, America, tonight, three hours, four hours, first, Democrat, Republican, Hispanic, Asian, Native American, Americans, the United States of America, tonight, America, Washington, Des Moines, Concord, Charleston, $5 and $10 and $20, millions, Americans, more than two centuries later, Earth, tonight, tomorrow, two, a century, tonight, Americans, Iraq, Afghanistan, one year, one, America, tonight, America, 221 years, 21 months ago, winter, this autumn night, Main Street, one, one, first, the Republican Party, the White House, the Democratic Party, tonight, Lincoln, Americans, tonight, tonight, American, America, Tonight, America, America, tomorrow, tonight, Atlanta, millions, one, Ann Nixon Cooper, 106 years old, two, tonight, America, American, Montgomery, Birmingham, Selma, Atlanta, the moon, Berlin, this year, 106 years, America, hours, America, America, tonight, the next century, Ann Nixon Cooper, American]
# puntuacion de la categoria mapeada de texto con span
# {}
# oraciones presentes en el documento
# 83
# 1.5002649267612376
# float32

# %% [markdown]
# # Parte 2: preguntas

# %% [markdown]
# Para responder a cada una de las preguntas planteadas deberás aportar tanto el código fuente con el cual puedes conseguir la respuesta, como una explicación válida de la respuesta y de la forma de obtenerla.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 1.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
#los tokens represenan la cantidad de palabras que el texto de entrada tiene, incluyendo signos de puntuacion.
print("Numero de tokens en el documento con signos de puntuacion")
print(len(doc))

print("Numero de tokens en el documento sin signos de puntuacion")
#Una propiedad del token permita excluir los signos de puntacion (is_punct	Is the token punctuation?), en la funcion siguiente,
#se contara +1 si el token no integra signos de puntuacion. https://spacy.io/api/token
num_palabras_sin_puntuacion = sum(1 for token in doc if not token.is_punct)
print(num_palabras_sin_puntuacion)
# Out:
# Numero de tokens en el documento con signos de puntuacion
# 1939
# Numero de tokens en el documento sin signos de puntuacion
# 1732

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #Una propiedad del token permita excluir los signos de puntacion (is_punct	Is the token punctuation?), en la funcion siguiente,
# #se contara +1 si el token no integra signos de puntuacion. https://spacy.io/api/token

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 2.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas oraciones tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
print("oraciones presentes en el documento")
sents = list(doc.sents)
print(len(sents))
# Out:
# oraciones presentes en el documento
# 83

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #se aplica la funcion len, para ver los indices que presenta la variable sents, este atributo aplicado a la varaible doc
# #permite generar una neuva lista con la cantidad de oraciones, para separar las oraciones toma en cuenta los signos de puntuacion
# # que separan una horacion como '.', ';', ':', '!', '?', etc.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 3.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuál el número de palabras de la oración más grande? ¿Cual es dicha oración?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
sents = list(doc.sents)
oracion_mas_larga = max(sents, key=len)

numero_palabras = len(oracion_mas_larga)
print("Numero de palabras:",numero_palabras)
print("Oración más larga:", oracion_mas_larga.text)
# Out:
# Numero de palabras: 67
# Oración más larga: It drew strength from the not-so-young people who braved the bitter cold and scorching heat to knock on doors of perfect strangers, and from the millions of Americans who volunteered and organized and proved that more than two centuries later a government of the people, by the people, and for the people has not perished from the Earth.

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #pra obtener la oracion mas larga, se utiliza la propiedad doc.sents para extraer las oraciones
# #posterior se aplica la funcion max para obtener el valor de la lista con mayor longitud
# #finalmente se aplica la funcion len para obtener la cantidad de palabras en la oracion.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 4.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes obtener el lema, el sufijo y el análisis morfológico de cada token?</span>
#
# Recomendación: si no lo has hecho ya, visita la documentación de la clase <i>Token</i>: https://spacy.io/api/token

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
for token in doc:
    # propeidad del token lemma_ (obtener el lema en forma de texto), alternativa lemma (otbener el lema como objeto lemma, recuperando las detalles del lema)
    lema = token.lemma_
    
    # propeidad del token suffix_(sufijo en forma de texto), suffix (el valor del objeto sufijo con mas propeidades), donde se obtiene las
    #ultimas letras del token
    sufijo = token.suffix_
    
    # propeidad que obtiene el analisis morfologico, disponigle unicamente en la version 3.0 de spacy y extrae la caracteristica del token, como 
    #si la palabra es singular, es un signo de puntuacion como ',', '.', etc.
    analisis_morfologico = token.morph
    
    print("Token:", token.text)
    print("Lema:", lema)
    print("Sufijo:", sufijo)
    print("Análisis Morfológico:", analisis_morfologico)
    print()
# Out:
# Token: “
# Lema: "
# Sufijo: “
# Análisis Morfológico: PunctSide=Ini|PunctType=Quot
#
# Token: Hello
# Lema: Hello
# Sufijo: llo
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: Chicago
# Lema: Chicago
# Sufijo: ago
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: If
# Lema: if
# Sufijo: If
# Análisis Morfológico:
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis Morfológico:
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: anyone
# Lema: anyone
# Sufijo: one
# Análisis Morfológico: Number=Sing|PronType=Ind
#
# Token: out
# Lema: out
# Sufijo: out
# Análisis Morfológico:
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis Morfológico: PronType=Dem
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: still
# Lema: still
# Sufijo: ill
# Análisis Morfológico:
#
# Token: doubts
# Lema: doubt
# Sufijo: bts
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis Morfológico: Number=Sing
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: place
# Lema: place
# Sufijo: ace
# Análisis Morfológico: Number=Sing
#
# Token: where
# Lema: where
# Sufijo: ere
# Análisis Morfológico:
#
# Token: all
# Lema: all
# Sufijo: all
# Análisis Morfológico:
#
# Token: things
# Lema: thing
# Sufijo: ngs
# Análisis Morfológico: Number=Plur
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: possible
# Lema: possible
# Sufijo: ble
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: still
# Lema: still
# Sufijo: ill
# Análisis Morfológico:
#
# Token: wonders
# Lema: wonder
# Sufijo: ers
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: if
# Lema: if
# Sufijo: if
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: dream
# Lema: dream
# Sufijo: eam
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: founders
# Lema: founder
# Sufijo: ers
# Análisis Morfológico: Number=Plur
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: alive
# Lema: alive
# Sufijo: ive
# Análisis Morfológico: Degree=Pos
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: still
# Lema: still
# Sufijo: ill
# Análisis Morfológico:
#
# Token: questions
# Lema: question
# Sufijo: ons
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: power
# Lema: power
# Sufijo: wer
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: democracy
# Lema: democracy
# Sufijo: acy
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis Morfológico: Number=Sing
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: your
# Lema: your
# Sufijo: our
# Análisis Morfológico: Person=2|Poss=Yes|PronType=Prs
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis Morfológico: Number=Sing
#
# Token: told
# Lema: tell
# Sufijo: old
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis Morfológico:
#
# Token: lines
# Lema: line
# Sufijo: nes
# Análisis Morfológico: Number=Plur
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: PronType=Rel
#
# Token: stretched
# Lema: stretch
# Sufijo: hed
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: around
# Lema: around
# Sufijo: und
# Análisis Morfológico:
#
# Token: schools
# Lema: school
# Sufijo: ols
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: churches
# Lema: church
# Sufijo: hes
# Análisis Morfológico: Number=Plur
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: numbers
# Lema: number
# Sufijo: ers
# Análisis Morfológico: Number=Plur
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: nation
# Lema: nation
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: has
# Lema: have
# Sufijo: has
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: never
# Lema: never
# Sufijo: ver
# Análisis Morfológico:
#
# Token: seen
# Lema: see
# Sufijo: een
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis Morfológico:
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: waited
# Lema: wait
# Sufijo: ted
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: three
# Lema: three
# Sufijo: ree
# Análisis Morfológico: NumType=Card
#
# Token: hours
# Lema: hour
# Sufijo: urs
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: four
# Lema: four
# Sufijo: our
# Análisis Morfológico: NumType=Card
#
# Token: hours
# Lema: hour
# Sufijo: urs
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis Morfológico: Degree=Pos
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: first
# Lema: first
# Sufijo: rst
# Análisis Morfológico: Degree=Pos
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis Morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: lives
# Lema: life
# Sufijo: ves
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis Morfológico:
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: believed
# Lema: believe
# Sufijo: ved
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis Morfológico: Number=Sing
#
# Token: must
# Lema: must
# Sufijo: ust
# Análisis Morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: different
# Lema: different
# Sufijo: ent
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: voices
# Lema: voice
# Sufijo: ces
# Análisis Morfológico: Number=Plur
#
# Token: could
# Lema: could
# Sufijo: uld
# Análisis Morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: difference
# Lema: difference
# Sufijo: nce
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis Morfológico: Number=Sing
#
# Token: spoken
# Lema: speak
# Sufijo: ken
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis Morfológico:
#
# Token: young
# Lema: young
# Sufijo: ung
# Análisis Morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: old
# Lema: old
# Sufijo: old
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: rich
# Lema: rich
# Sufijo: ich
# Análisis Morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: poor
# Lema: poor
# Sufijo: oor
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: Democrat
# Lema: Democrat
# Sufijo: rat
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: Republican
# Lema: Republican
# Sufijo: can
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: black
# Lema: black
# Sufijo: ack
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: white
# Lema: white
# Sufijo: ite
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: Hispanic
# Lema: hispanic
# Sufijo: nic
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: Asian
# Lema: asian
# Sufijo: ian
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: Native
# Lema: Native
# Sufijo: ive
# Análisis Morfológico: Number=Sing
#
# Token: American
# Lema: American
# Sufijo: can
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: gay
# Lema: gay
# Sufijo: gay
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: straight
# Lema: straight
# Sufijo: ght
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: disabled
# Lema: disabled
# Sufijo: led
# Análisis Morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis Morfológico: Polarity=Neg
#
# Token: disabled
# Lema: disabled
# Sufijo: led
# Análisis Morfológico: Degree=Pos
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: Americans
# Lema: american
# Sufijo: ans
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: sent
# Lema: send
# Sufijo: ent
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: message
# Lema: message
# Sufijo: age
# Análisis Morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: world
# Lema: world
# Sufijo: rld
# Análisis Morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: never
# Lema: never
# Sufijo: ver
# Análisis Morfológico:
#
# Token: been
# Lema: be
# Sufijo: een
# Análisis Morfológico: Tense=Past|VerbForm=Part
#
# Token: just
# Lema: just
# Sufijo: ust
# Análisis Morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: collection
# Lema: collection
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: individuals
# Lema: individual
# Sufijo: als
# Análisis Morfológico: Number=Plur
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis Morfológico: ConjType=Cmp
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: collection
# Lema: collection
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: red
# Lema: red
# Sufijo: red
# Análisis Morfológico: Degree=Pos
#
# Token: states
# Lema: state
# Sufijo: tes
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: blue
# Lema: blue
# Sufijo: lue
# Análisis Morfológico: Degree=Pos
#
# Token: states
# Lema: state
# Sufijo: tes
# Análisis Morfológico: Number=Plur
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: We
# Lema: we
# Sufijo: We
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: always
# Lema: always
# Sufijo: ays
# Análisis Morfológico:
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: United
# Lema: United
# Sufijo: ted
# Análisis Morfológico: Number=Sing
#
# Token: States
# Lema: States
# Sufijo: tes
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis Morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: PronType=Rel
#
# Token: led
# Lema: lead
# Sufijo: led
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: those
# Lema: those
# Sufijo: ose
# Análisis Morfológico: Number=Plur|PronType=Dem
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: ’ve
# Lema: ’ve
# Sufijo: ’ve
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: been
# Lema: been
# Sufijo: een
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: told
# Lema: tell
# Sufijo: old
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis Morfológico:
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis Morfológico:
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis Morfológico: Degree=Pos
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: cynical
# Lema: cynical
# Sufijo: cal
# Análisis Morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: fearful
# Lema: fearful
# Sufijo: ful
# Análisis Morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: doubtful
# Lema: doubtful
# Sufijo: ful
# Análisis Morfológico: Degree=Pos
#
# Token: about
# Lema: about
# Sufijo: out
# Análisis Morfológico:
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis Morfológico: VerbForm=Fin
#
# Token: achieve
# Lema: achieve
# Sufijo: eve
# Análisis Morfológico: VerbForm=Inf
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: put
# Lema: put
# Sufijo: put
# Análisis Morfológico: VerbForm=Inf
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: hands
# Lema: hand
# Sufijo: nds
# Análisis Morfológico: Number=Plur
#
# Token: on
# Lema: on
# Sufijo: on
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: arc
# Lema: arc
# Sufijo: arc
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: history
# Lema: history
# Sufijo: ory
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: bend
# Lema: bend
# Sufijo: end
# Análisis Morfológico: VerbForm=Inf
#
# Token: it
# Lema: it
# Sufijo: it
# Análisis Morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: once
# Lema: once
# Sufijo: nce
# Análisis Morfológico: NumType=Mult
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis Morfológico: Degree=Cmp
#
# Token: toward
# Lema: toward
# Sufijo: ard
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: hope
# Lema: hope
# Sufijo: ope
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: better
# Lema: well
# Sufijo: ter
# Análisis Morfológico: Degree=Cmp
#
# Token: day
# Lema: day
# Sufijo: day
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’s
# Sufijo: ’s
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: been
# Lema: be
# Sufijo: een
# Análisis Morfológico: Tense=Past|VerbForm=Part
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis Morfológico: Degree=Pos
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis Morfológico: Number=Sing
#
# Token: coming
# Lema: come
# Sufijo: ing
# Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: but
# Lema: but
# Sufijo: but
# Análisis Morfológico: ConjType=Cmp
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis Morfológico:
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: on
# Lema: on
# Sufijo: on
# Análisis Morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: date
# Lema: date
# Sufijo: ate
# Análisis Morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: election
# Lema: election
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: at
# Lema: at
# Sufijo: at
# Análisis Morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: defining
# Lema: define
# Sufijo: ing
# Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: moment
# Lema: moment
# Sufijo: ent
# Análisis Morfológico: Number=Sing
#
# Token: change
# Lema: change
# Sufijo: nge
# Análisis Morfológico: Number=Sing
#
# Token: has
# Lema: have
# Sufijo: has
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: come
# Lema: come
# Sufijo: ome
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: [
# Lema: [
# Sufijo: [
# Análisis Morfológico: PunctSide=Ini|PunctType=Brck
#
# Token: read
# Lema: read
# Sufijo: ead
# Análisis Morfológico: VerbForm=Inf
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis Morfológico: Degree=Cmp
#
# Token: ]
# Lema: ]
# Sufijo: ]
# Análisis Morfológico: PunctSide=Fin|PunctType=Brck
#
# Token:
#
#
# Lema:
#
#
# Sufijo:
#
#
# Análisis Morfológico:
#
# Token: We
# Lema: we
# Sufijo: We
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis Morfológico: Polarity=Neg
#
# Token: start
# Lema: start
# Sufijo: art
# Análisis Morfológico: VerbForm=Inf
#
# Token: with
# Lema: with
# Sufijo: ith
# Análisis Morfológico:
#
# Token: much
# Lema: much
# Sufijo: uch
# Análisis Morfológico: Degree=Pos
#
# Token: money
# Lema: money
# Sufijo: ney
# Análisis Morfológico: Number=Sing
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis Morfológico: ConjType=Cmp
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis Morfológico: Degree=Pos
#
# Token: endorsements
# Lema: endorsement
# Sufijo: nts
# Análisis Morfológico: Number=Plur
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: Our
# Lema: our
# Sufijo: Our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: campaign
# Lema: campaign
# Sufijo: ign
# Análisis Morfológico: Number=Sing
#
# Token: was
# Lema: be
# Sufijo: was
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis Morfológico: Polarity=Neg
#
# Token: hatched
# Lema: hatch
# Sufijo: hed
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: halls
# Lema: hall
# Sufijo: lls
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Washington
# Lema: Washington
# Sufijo: ton
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: began
# Lema: begin
# Sufijo: gan
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: backyards
# Lema: backyard
# Sufijo: rds
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Des
# Lema: Des
# Sufijo: Des
# Análisis Morfológico: Number=Sing
#
# Token: Moines
# Lema: Moines
# Sufijo: nes
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: living
# Lema: live
# Sufijo: ing
# Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: rooms
# Lema: room
# Sufijo: oms
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Concord
# Lema: Concord
# Sufijo: ord
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: front
# Lema: front
# Sufijo: ont
# Análisis Morfológico: Degree=Pos
#
# Token: porches
# Lema: porch
# Sufijo: hes
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Charleston
# Lema: Charleston
# Sufijo: ton
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: was
# Lema: be
# Sufijo: was
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
#
# Token: built
# Lema: build
# Sufijo: ilt
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis Morfológico:
#
# Token: working
# Lema: work
# Sufijo: ing
# Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: men
# Lema: man
# Sufijo: men
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: women
# Lema: woman
# Sufijo: men
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: dug
# Lema: dig
# Sufijo: dug
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: into
# Lema: into
# Sufijo: nto
# Análisis Morfológico:
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis Morfológico:
#
# Token: little
# Lema: little
# Sufijo: tle
# Análisis Morfológico: Degree=Pos
#
# Token: savings
# Lema: saving
# Sufijo: ngs
# Análisis Morfológico: Number=Plur
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: had
# Lema: have
# Sufijo: had
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: give
# Lema: give
# Sufijo: ive
# Análisis Morfológico: VerbForm=Inf
#
# Token: $
# Lema: $
# Sufijo: $
# Análisis Morfológico:
#
# Token: 5
# Lema: 5
# Sufijo: 5
# Análisis Morfológico: NumType=Card
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: $
# Lema: $
# Sufijo: $
# Análisis Morfológico:
#
# Token: 10
# Lema: 10
# Sufijo: 10
# Análisis Morfológico: NumType=Card
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: $
# Lema: $
# Sufijo: $
# Análisis Morfológico:
#
# Token: 20
# Lema: 20
# Sufijo: 20
# Análisis Morfológico: NumType=Card
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: cause
# Lema: cause
# Sufijo: use
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: grew
# Lema: grow
# Sufijo: rew
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: strength
# Lema: strength
# Sufijo: gth
# Análisis Morfológico: Number=Sing
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: young
# Lema: young
# Sufijo: ung
# Análisis Morfológico: Degree=Pos
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: rejected
# Lema: reject
# Sufijo: ted
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: myth
# Lema: myth
# Sufijo: yth
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: generation
# Lema: generation
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: ’s
# Lema: ’s
# Sufijo: ’s
# Análisis Morfológico:
#
# Token: apathy
# Lema: apathy
# Sufijo: thy
# Análisis Morfológico: Degree=Pos
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: left
# Lema: leave
# Sufijo: eft
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: homes
# Lema: home
# Sufijo: mes
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: families
# Lema: family
# Sufijo: ies
# Análisis Morfológico: Number=Plur
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: jobs
# Lema: job
# Sufijo: obs
# Análisis Morfológico: Number=Plur
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: PronType=Rel
#
# Token: offered
# Lema: offer
# Sufijo: red
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: little
# Lema: little
# Sufijo: tle
# Análisis Morfológico: Degree=Pos
#
# Token: pay
# Lema: pay
# Sufijo: pay
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: less
# Lema: less
# Sufijo: ess
# Análisis Morfológico: Degree=Cmp
#
# Token: sleep
# Lema: sleep
# Sufijo: eep
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: drew
# Lema: draw
# Sufijo: rew
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: strength
# Lema: strength
# Sufijo: gth
# Análisis Morfológico: Number=Sing
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis Morfológico: Polarity=Neg
#
# Token: -
# Lema: -
# Sufijo: -
# Análisis Morfológico: PunctType=Dash
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: -
# Lema: -
# Sufijo: -
# Análisis Morfológico: PunctType=Dash
#
# Token: young
# Lema: young
# Sufijo: ung
# Análisis Morfológico: Degree=Pos
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: braved
# Lema: brave
# Sufijo: ved
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: bitter
# Lema: bitter
# Sufijo: ter
# Análisis Morfológico: Degree=Pos
#
# Token: cold
# Lema: cold
# Sufijo: old
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: scorching
# Lema: scorch
# Sufijo: ing
# Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: heat
# Lema: heat
# Sufijo: eat
# Análisis Morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: knock
# Lema: knock
# Sufijo: ock
# Análisis Morfológico: VerbForm=Inf
#
# Token: on
# Lema: on
# Sufijo: on
# Análisis Morfológico:
#
# Token: doors
# Lema: door
# Sufijo: ors
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: perfect
# Lema: perfect
# Sufijo: ect
# Análisis Morfológico: Degree=Pos
#
# Token: strangers
# Lema: stranger
# Sufijo: ers
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: millions
# Lema: million
# Sufijo: ons
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Americans
# Lema: Americans
# Sufijo: ans
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: volunteered
# Lema: volunteer
# Sufijo: red
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: organized
# Lema: organize
# Sufijo: zed
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: proved
# Lema: prove
# Sufijo: ved
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis Morfológico: Degree=Cmp
#
# Token: than
# Lema: than
# Sufijo: han
# Análisis Morfológico:
#
# Token: two
# Lema: two
# Sufijo: two
# Análisis Morfológico: NumType=Card
#
# Token: centuries
# Lema: century
# Sufijo: ies
# Análisis Morfológico: Number=Plur
#
# Token: later
# Lema: later
# Sufijo: ter
# Análisis Morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: government
# Lema: government
# Sufijo: ent
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: has
# Lema: have
# Sufijo: has
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis Morfológico: Polarity=Neg
#
# Token: perished
# Lema: perish
# Sufijo: hed
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: Earth
# Lema: Earth
# Sufijo: rth
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: your
# Lema: your
# Sufijo: our
# Análisis Morfológico: Person=2|Poss=Yes|PronType=Prs
#
# Token: victory
# Lema: victory
# Sufijo: ory
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: And
# Lema: and
# Sufijo: And
# Análisis Morfológico: ConjType=Cmp
#
# Token: I
# Lema: I
# Sufijo: I
# Análisis Morfológico: Case=Nom|Number=Sing|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: you
# Lema: you
# Sufijo: you
# Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis Morfológico: Polarity=Neg
#
# Token: do
# Lema: do
# Sufijo: do
# Análisis Morfológico: VerbForm=Inf
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: just
# Lema: just
# Sufijo: ust
# Análisis Morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: win
# Lema: win
# Sufijo: win
# Análisis Morfológico: VerbForm=Inf
#
# Token: an
# Lema: an
# Sufijo: an
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: election
# Lema: election
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: And
# Lema: and
# Sufijo: And
# Análisis Morfológico: ConjType=Cmp
#
# Token: I
# Lema: I
# Sufijo: I
# Análisis Morfológico: Case=Nom|Number=Sing|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: you
# Lema: you
# Sufijo: you
# Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis Morfológico: Polarity=Neg
#
# Token: do
# Lema: do
# Sufijo: do
# Análisis Morfológico: VerbForm=Inf
#
# Token: it
# Lema: it
# Sufijo: it
# Análisis Morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: me
# Lema: I
# Sufijo: me
# Análisis Morfológico: Case=Acc|Number=Sing|Person=1|PronType=Prs
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: You
# Lema: you
# Sufijo: You
# Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis Morfológico: Tense=Past|VerbForm=Fin
#
# Token: it
# Lema: it
# Sufijo: it
# Análisis Morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis Morfológico:
#
# Token: you
# Lema: you
# Sufijo: you
# Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: understand
# Lema: understand
# Sufijo: and
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: enormity
# Lema: enormity
# Sufijo: ity
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: task
# Lema: task
# Sufijo: ask
# Análisis Morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: PronType=Rel
#
# Token: lies
# Lema: lie
# Sufijo: ies
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: ahead
# Lema: ahead
# Sufijo: ead
# Análisis Morfológico:
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: For
# Lema: for
# Sufijo: For
# Análisis Morfológico:
#
# Token: even
# Lema: even
# Sufijo: ven
# Análisis Morfológico:
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: celebrate
# Lema: celebrate
# Sufijo: ate
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: challenges
# Lema: challenge
# Sufijo: ges
# Análisis Morfológico: Number=Plur
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: PronType=Rel
#
# Token: tomorrow
# Lema: tomorrow
# Sufijo: row
# Análisis Morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: bring
# Lema: bring
# Sufijo: ing
# Análisis Morfológico: VerbForm=Inf
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: greatest
# Lema: great
# Sufijo: est
# Análisis Morfológico: Degree=Sup
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: lifetime
# Lema: lifetime
# Sufijo: ime
# Análisis Morfológico: Number=Sing
#
# Token: —
# Lema: —
# Sufijo: —
# Análisis Morfológico:
#
# Token: two
# Lema: two
# Sufijo: two
# Análisis Morfológico: NumType=Card
#
# Token: wars
# Lema: war
# Sufijo: ars
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: planet
# Lema: planet
# Sufijo: net
# Análisis Morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: peril
# Lema: peril
# Sufijo: ril
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: worst
# Lema: bad
# Sufijo: rst
# Análisis Morfológico: Degree=Sup
#
# Token: financial
# Lema: financial
# Sufijo: ial
# Análisis Morfológico: Degree=Pos
#
# Token: crisis
# Lema: crisis
# Sufijo: sis
# Análisis Morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: century
# Lema: century
# Sufijo: ury
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: Even
# Lema: even
# Sufijo: ven
# Análisis Morfológico:
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: stand
# Lema: stand
# Sufijo: and
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: here
# Lema: here
# Sufijo: ere
# Análisis Morfológico: PronType=Dem
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis Morfológico:
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: brave
# Lema: brave
# Sufijo: ave
# Análisis Morfológico: Degree=Pos
#
# Token: Americans
# Lema: Americans
# Sufijo: ans
# Análisis Morfológico: Number=Plur
#
# Token: waking
# Lema: wake
# Sufijo: ing
# Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: up
# Lema: up
# Sufijo: up
# Análisis Morfológico:
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: deserts
# Lema: desert
# Sufijo: rts
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Iraq
# Lema: Iraq
# Sufijo: raq
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: mountains
# Lema: mountain
# Sufijo: ins
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: Afghanistan
# Lema: Afghanistan
# Sufijo: tan
# Análisis Morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: risk
# Lema: risk
# Sufijo: isk
# Análisis Morfológico: VerbForm=Inf
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: lives
# Lema: life
# Sufijo: ves
# Análisis Morfológico: Number=Plur
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: us
# Lema: we
# Sufijo: us
# Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: There
# Lema: there
# Sufijo: ere
# Análisis Morfológico:
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: mothers
# Lema: mother
# Sufijo: ers
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: fathers
# Lema: father
# Sufijo: ers
# Análisis Morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: lie
# Lema: lie
# Sufijo: lie
# Análisis Morfológico: VerbForm=Inf
#
# Token: awake
# Lema: awake
# Sufijo: ake
# Análisis Morfológico: Degree=Pos
#
# Token: after
# Lema: after
# Sufijo: ter
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: children
# Lema: child
# Sufijo: ren
# Análisis Morfológico: Number=Plur
#
# Token: fall
# Lema: fall
# Sufijo: all
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: asleep
# Lema: asleep
# Sufijo: eep
# Análisis Morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: wonder
# Lema: wonder
# Sufijo: der
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: how
# Lema: how
# Sufijo: how
# Análisis Morfológico:
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: ’ll
# Lema: ’ll
# Sufijo: ’ll
# Análisis Morfológico: VerbType=Mod
#
# Token: make
# Lema: make
# Sufijo: ake
# Análisis Morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: mortgage
# Lema: mortgage
# Sufijo: age
# Análisis Morfológico: Number=Sing
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis Morfológico: ConjType=Cmp
#
# Token: pay
# Lema: pay
# Sufijo: pay
# Análisis Morfológico: VerbForm=Inf
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: doctors
# Lema: doctor
# Sufijo: ors
# Análisis Morfológico: Number=Plur
#
# Token: ’
# Lema: ’
# Sufijo: ’
# Análisis Morfológico:
#
# Token: bills
# Lema: bill
# Sufijo: lls
# Análisis Morfológico: Number=Plur
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis Morfológico: ConjType=Cmp
#
# Token: save
# Lema: save
# Sufijo: ave
# Análisis Morfológico: VerbForm=Inf
#
# Token: enough
# Lema: enough
# Sufijo: ugh
# Análisis Morfológico: Degree=Pos
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: child
# Lema: child
# Sufijo: ild
# Análisis Morfológico: Number=Sing
#
# Token: ’s
# Lema: ’s
# Sufijo: ’s
# Análisis Morfológico:
#
# Token: college
# Lema: college
# Sufijo: ege
# Análisis Morfológico: Number=Sing
#
# Token: education
# Lema: education
# Sufijo: ion
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: There
# Lema: there
# Sufijo: ere
# Análisis Morfológico:
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: new
# Lema: new
# Sufijo: new
# Análisis Morfológico: Degree=Pos
#
# Token: energy
# Lema: energy
# Sufijo: rgy
# Análisis Morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: harness
# Lema: harness
# Sufijo: ess
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: new
# Lema: new
# Sufijo: new
# Análisis Morfológico: Degree=Pos
#
# Token: jobs
# Lema: job
# Sufijo: obs
# Análisis Morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: created
# Lema: create
# Sufijo: ted
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: new
# Lema: new
# Sufijo: new
# Análisis Morfológico: Degree=Pos
#
# Token: schools
# Lema: school
# Sufijo: ols
# Análisis Morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: build
# Lema: build
# Sufijo: ild
# Análisis Morfológico: VerbForm=Inf
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: threats
# Lema: threat
# Sufijo: ats
# Análisis Morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: meet
# Lema: meet
# Sufijo: eet
# Análisis Morfológico: VerbForm=Inf
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: alliances
# Lema: alliance
# Sufijo: ces
# Análisis Morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: repair
# Lema: repair
# Sufijo: air
# Análisis Morfológico: VerbForm=Inf
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: The
# Lema: the
# Sufijo: The
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: road
# Lema: road
# Sufijo: oad
# Análisis Morfológico: Number=Sing
#
# Token: ahead
# Lema: ahead
# Sufijo: ead
# Análisis Morfológico:
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis Morfológico: Degree=Pos
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: Our
# Lema: our
# Sufijo: Our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: climb
# Lema: climb
# Sufijo: imb
# Análisis Morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# ...
#
# Token: vote
# Lema: vote
# Sufijo: ote
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis Morfológico:
#
# Token: after
# Lema: after
# Sufijo: ter
# Análisis Morfológico:
#
# Token: 106
# Lema: 106
# Sufijo: 106
# Análisis Morfológico: NumType=Card
#
# Token: years
# Lema: year
# Sufijo: ars
# Análisis Morfológico: Number=Plur
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis Morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: through
# Lema: through
# Sufijo: ugh
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: best
# Lema: good
# Sufijo: est
# Análisis Morfológico: Degree=Sup
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: times
# Lema: time
# Sufijo: mes
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: darkest
# Lema: darkest
# Sufijo: est
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: hours
# Lema: hour
# Sufijo: urs
# Análisis Morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: she
# Lema: she
# Sufijo: she
# Análisis Morfológico: Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
#
# Token: knows
# Lema: know
# Sufijo: ows
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: how
# Lema: how
# Sufijo: how
# Análisis Morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis Morfológico: Number=Sing
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis Morfológico: VerbForm=Fin
#
# Token: change
# Lema: change
# Sufijo: nge
# Análisis Morfológico: VerbForm=Inf
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: Yes
# Lema: yes
# Sufijo: Yes
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis Morfológico: VerbForm=Fin
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: come
# Lema: come
# Sufijo: ome
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: far
# Lema: far
# Sufijo: far
# Análisis Morfológico:
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: We
# Lema: we
# Sufijo: We
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: seen
# Lema: see
# Sufijo: een
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: much
# Lema: much
# Sufijo: uch
# Análisis Morfológico: Degree=Pos
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: But
# Lema: but
# Sufijo: But
# Análisis Morfológico: ConjType=Cmp
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis Morfológico:
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: much
# Lema: much
# Sufijo: uch
# Análisis Morfológico:
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis Morfológico: Degree=Cmp
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: do
# Lema: do
# Sufijo: do
# Análisis Morfológico: VerbForm=Inf
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: So
# Lema: so
# Sufijo: So
# Análisis Morfológico:
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: let
# Lema: let
# Sufijo: let
# Análisis Morfológico: VerbForm=Inf
#
# Token: us
# Lema: we
# Sufijo: us
# Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
#
# Token: ask
# Lema: ask
# Sufijo: ask
# Análisis Morfológico: VerbForm=Inf
#
# Token: ourselves
# Lema: ourselves
# Sufijo: ves
# Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs|Reflex=Yes
#
# Token: —
# Lema: —
# Sufijo: —
# Análisis Morfológico:
#
# Token: if
# Lema: if
# Sufijo: if
# Análisis Morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: children
# Lema: child
# Sufijo: ren
# Análisis Morfológico: Number=Plur
#
# Token: should
# Lema: should
# Sufijo: uld
# Análisis Morfológico: VerbForm=Fin
#
# Token: live
# Lema: live
# Sufijo: ive
# Análisis Morfológico: VerbForm=Inf
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: see
# Lema: see
# Sufijo: see
# Análisis Morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: next
# Lema: next
# Sufijo: ext
# Análisis Morfológico: Degree=Pos
#
# Token: century
# Lema: century
# Sufijo: ury
# Análisis Morfológico: Number=Sing
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis Morfológico:
#
# Token: if
# Lema: if
# Sufijo: if
# Análisis Morfológico:
#
# Token: my
# Lema: my
# Sufijo: my
# Análisis Morfológico: Number=Sing|Person=1|Poss=Yes|PronType=Prs
#
# Token: daughters
# Lema: daughter
# Sufijo: ers
# Análisis Morfológico: Number=Plur
#
# Token: should
# Lema: should
# Sufijo: uld
# Análisis Morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis Morfológico: VerbForm=Inf
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis Morfológico:
#
# Token: lucky
# Lema: lucky
# Sufijo: cky
# Análisis Morfológico: Degree=Pos
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: live
# Lema: live
# Sufijo: ive
# Análisis Morfológico: VerbForm=Inf
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis Morfológico:
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis Morfológico:
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis Morfológico:
#
# Token: Ann
# Lema: Ann
# Sufijo: Ann
# Análisis Morfológico: Number=Sing
#
# Token: Nixon
# Lema: Nixon
# Sufijo: xon
# Análisis Morfológico: Number=Sing
#
# Token: Cooper
# Lema: Cooper
# Sufijo: per
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis Morfológico:
#
# Token: change
# Lema: change
# Sufijo: nge
# Análisis Morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: see
# Lema: see
# Sufijo: see
# Análisis Morfológico: VerbForm=Inf
#
# Token: ?
# Lema: ?
# Sufijo: ?
# Análisis Morfológico: PunctType=Peri
#
# Token: What
# Lema: what
# Sufijo: hat
# Análisis Morfológico:
#
# Token: progress
# Lema: progress
# Sufijo: ess
# Análisis Morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis Morfológico: VerbForm=Inf
#
# Token: made
# Lema: make
# Sufijo: ade
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: ?
# Lema: ?
# Sufijo: ?
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: chance
# Lema: chance
# Sufijo: nce
# Análisis Morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis Morfológico: VerbForm=Inf
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: call
# Lema: call
# Sufijo: all
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: moment
# Lema: moment
# Sufijo: ent
# Análisis Morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis Morfológico:
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: put
# Lema: put
# Sufijo: put
# Análisis Morfológico: VerbForm=Inf
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: back
# Lema: back
# Sufijo: ack
# Análisis Morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: work
# Lema: work
# Sufijo: ork
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: open
# Lema: open
# Sufijo: pen
# Análisis Morfológico: Degree=Pos
#
# Token: doors
# Lema: door
# Sufijo: ors
# Análisis Morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: opportunity
# Lema: opportunity
# Sufijo: ity
# Análisis Morfológico: Number=Sing
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis Morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: kids
# Lema: kid
# Sufijo: ids
# Análisis Morfológico: Number=Plur
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis Morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: restore
# Lema: restore
# Sufijo: ore
# Análisis Morfológico: VerbForm=Inf
#
# Token: prosperity
# Lema: prosperity
# Sufijo: ity
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: promote
# Lema: promote
# Sufijo: ote
# Análisis Morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: cause
# Lema: cause
# Sufijo: use
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: peace
# Lema: peace
# Sufijo: ace
# Análisis Morfológico: Number=Sing
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis Morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis Morfológico:
#
# Token: reclaim
# Lema: reclaim
# Sufijo: aim
# Análisis Morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: American
# Lema: american
# Sufijo: can
# Análisis Morfológico: Degree=Pos
#
# Token: dream
# Lema: dream
# Sufijo: eam
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: reaffirm
# Lema: reaffirm
# Sufijo: irm
# Análisis Morfológico: VerbForm=Inf
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: fundamental
# Lema: fundamental
# Sufijo: tal
# Análisis Morfológico: Degree=Pos
#
# Token: truth
# Lema: truth
# Sufijo: uth
# Análisis Morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: out
# Lema: out
# Sufijo: out
# Análisis Morfológico:
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis Morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: one
# Lema: one
# Sufijo: one
# Análisis Morfológico: NumType=Card
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis Morfológico:
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: while
# Lema: while
# Sufijo: ile
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: breathe
# Lema: breathe
# Sufijo: the
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: hope
# Lema: hope
# Sufijo: ope
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: And
# Lema: and
# Sufijo: And
# Análisis Morfológico: ConjType=Cmp
#
# Token: where
# Lema: where
# Sufijo: ere
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: met
# Lema: meet
# Sufijo: met
# Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: with
# Lema: with
# Sufijo: ith
# Análisis Morfológico:
#
# Token: cynicism
# Lema: cynicism
# Sufijo: ism
# Análisis Morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: doubts
# Lema: doubt
# Sufijo: bts
# Análisis Morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis Morfológico: ConjType=Cmp
#
# Token: those
# Lema: those
# Sufijo: ose
# Análisis Morfológico: Number=Plur|PronType=Dem
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis Morfológico:
#
# Token: tell
# Lema: tell
# Sufijo: ell
# Análisis Morfológico: Tense=Pres|VerbForm=Fin
#
# Token: us
# Lema: we
# Sufijo: us
# Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: ca
# Lema: can
# Sufijo: ca
# Análisis Morfológico: VerbType=Mod
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis Morfológico: Polarity=Neg
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis Morfológico: VerbForm=Fin
#
# Token: respond
# Lema: respond
# Sufijo: ond
# Análisis Morfológico: VerbForm=Inf
#
# Token: with
# Lema: with
# Sufijo: ith
# Análisis Morfológico:
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: Number=Sing|PronType=Dem
#
# Token: timeless
# Lema: timeless
# Sufijo: ess
# Análisis Morfológico: Number=Sing
#
# Token: creed
# Lema: creed
# Sufijo: eed
# Análisis Morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis Morfológico: PronType=Rel
#
# Token: sums
# Lema: sum
# Sufijo: ums
# Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: up
# Lema: up
# Sufijo: up
# Análisis Morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis Morfológico: Definite=Def|PronType=Art
#
# Token: spirit
# Lema: spirit
# Sufijo: rit
# Análisis Morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis Morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis Morfológico: Definite=Ind|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis Morfológico: Number=Plur
#
# Token: :
# Lema: :
# Sufijo: :
# Análisis Morfológico:
#
# Token: Yes
# Lema: yes
# Sufijo: Yes
# Análisis Morfológico:
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis Morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis Morfológico: VerbForm=Fin
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis Morfológico: PunctType=Peri
#
# Token: [
# Lema: [
# Sufijo: [
# Análisis Morfológico:

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# # propeidad del token lemma_ (obtener el lema en forma de texto), alternativa lemma (otbener el lema como objeto lemma, recuperando las detalles del lema)
# # propeidad del token suffix_(sufijo en forma de texto), suffix (el valor del objeto sufijo con mas propeidades), donde se obtiene la
#     #ultimas letras del token
# # propeidad que obtiene el analisis morfologico, disponigle unicamente en la version 3.0 de spacy y extrae la caracteristica del token, como
#     #si la palabra es singular, es un signo de puntuacion como ',', '.', etc.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 5.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes identificar/eliminar las stop words?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
palabras_sin_stopwords = []
for token in doc:
    #se imprime los tokens stop words
    if token.is_stop:
        print("stop word:", token.text)
        print()
    if not token.is_stop:
        palabras_sin_stopwords.append(token.text)
        
# Convertir la lista de palabras sin stop words a una cadena
texto_sin_stopwords = ' '.join(palabras_sin_stopwords)
print("Texto sin stop words:",texto_sin_stopwords)
# Out:
# stop word: If
#
# stop word: there
#
# stop word: is
#
# stop word: anyone
#
# stop word: out
#
# stop word: there
#
# stop word: who
#
# stop word: still
#
# stop word: that
#
# stop word: is
#
# stop word: a
#
# stop word: where
#
# stop word: all
#
# stop word: are
#
# stop word: who
#
# stop word: still
#
# stop word: if
#
# stop word: the
#
# stop word: of
#
# stop word: our
#
# stop word: is
#
# stop word: in
#
# stop word: our
#
# stop word: who
#
# stop word: still
#
# stop word: the
#
# stop word: of
#
# stop word: our
#
# stop word: is
#
# stop word: your
#
# stop word: It
#
# stop word: ’s
#
# stop word: the
#
# stop word: by
#
# stop word: that
#
# stop word: around
#
# stop word: and
#
# stop word: in
#
# stop word: this
#
# stop word: has
#
# stop word: never
#
# stop word: by
#
# stop word: who
#
# stop word: three
#
# stop word: and
#
# stop word: four
#
# stop word: many
#
# stop word: for
#
# stop word: the
#
# stop word: first
#
# stop word: in
#
# stop word: their
#
# stop word: because
#
# stop word: they
#
# stop word: that
#
# stop word: this
#
# stop word: must
#
# stop word: be
#
# stop word: that
#
# stop word: their
#
# stop word: could
#
# stop word: be
#
# stop word: that
#
# stop word: It
#
# stop word: ’s
#
# stop word: the
#
# stop word: by
#
# stop word: and
#
# stop word: and
#
# stop word: and
#
# stop word: and
#
# stop word: not
#
# stop word: who
#
# stop word: a
#
# stop word: to
#
# stop word: the
#
# stop word: that
#
# stop word: we
#
# stop word: have
#
# stop word: never
#
# stop word: been
#
# stop word: just
#
# stop word: a
#
# stop word: of
#
# stop word: or
#
# stop word: a
#
# stop word: of
#
# stop word: and
#
# stop word: We
#
# stop word: are
#
# stop word: and
#
# stop word: always
#
# stop word: will
#
# stop word: be
#
# stop word: the
#
# stop word: of
#
# stop word: It
#
# stop word: ’s
#
# stop word: the
#
# stop word: that
#
# stop word: those
#
# stop word: who
#
# stop word: ’ve
#
# stop word: been
#
# stop word: for
#
# stop word: so
#
# stop word: by
#
# stop word: so
#
# stop word: many
#
# stop word: to
#
# stop word: be
#
# stop word: and
#
# stop word: and
#
# stop word: about
#
# stop word: what
#
# stop word: we
#
# stop word: can
#
# stop word: to
#
# stop word: put
#
# stop word: their
#
# stop word: on
#
# stop word: the
#
# stop word: of
#
# stop word: and
#
# stop word: it
#
# stop word: once
#
# stop word: more
#
# stop word: toward
#
# stop word: the
#
# stop word: of
#
# stop word: a
#
# stop word: It
#
# stop word: ’s
#
# stop word: been
#
# stop word: a
#
# stop word: but
#
# stop word: because
#
# stop word: of
#
# stop word: what
#
# stop word: we
#
# stop word: did
#
# stop word: on
#
# stop word: this
#
# stop word: in
#
# stop word: this
#
# stop word: at
#
# stop word: this
#
# stop word: has
#
# stop word: to
#
# stop word: more
#
# stop word: We
#
# stop word: did
#
# stop word: n’t
#
# stop word: with
#
# stop word: much
#
# stop word: or
#
# stop word: many
#
# stop word: Our
#
# stop word: was
#
# stop word: not
#
# stop word: in
#
# stop word: the
#
# stop word: of
#
# stop word: It
#
# stop word: in
#
# stop word: the
#
# stop word: of
#
# stop word: and
#
# stop word: the
#
# stop word: of
#
# stop word: and
#
# stop word: the
#
# stop word: front
#
# stop word: of
#
# stop word: It
#
# stop word: was
#
# stop word: by
#
# stop word: and
#
# stop word: who
#
# stop word: into
#
# stop word: what
#
# stop word: they
#
# stop word: had
#
# stop word: to
#
# stop word: give
#
# stop word: and
#
# stop word: and
#
# stop word: to
#
# stop word: the
#
# stop word: It
#
# stop word: from
#
# stop word: the
#
# stop word: who
#
# stop word: the
#
# stop word: of
#
# stop word: their
#
# stop word: ’s
#
# stop word: who
#
# stop word: their
#
# stop word: and
#
# stop word: their
#
# stop word: for
#
# stop word: that
#
# stop word: and
#
# stop word: less
#
# stop word: It
#
# stop word: from
#
# stop word: the
#
# stop word: not
#
# stop word: so
#
# stop word: who
#
# stop word: the
#
# stop word: and
#
# stop word: to
#
# stop word: on
#
# stop word: of
#
# stop word: and
#
# stop word: from
#
# stop word: the
#
# stop word: of
#
# stop word: who
#
# stop word: and
#
# stop word: and
#
# stop word: that
#
# stop word: more
#
# stop word: than
#
# stop word: two
#
# stop word: a
#
# stop word: of
#
# stop word: the
#
# stop word: by
#
# stop word: the
#
# stop word: and
#
# stop word: for
#
# stop word: the
#
# stop word: has
#
# stop word: not
#
# stop word: from
#
# stop word: the
#
# stop word: This
#
# stop word: is
#
# stop word: your
#
# stop word: And
#
# stop word: I
#
# stop word: you
#
# stop word: did
#
# stop word: n’t
#
# stop word: do
#
# stop word: this
#
# stop word: just
#
# stop word: to
#
# stop word: an
#
# stop word: And
#
# stop word: I
#
# stop word: you
#
# stop word: did
#
# stop word: n’t
#
# stop word: do
#
# stop word: it
#
# stop word: for
#
# stop word: me
#
# stop word: You
#
# stop word: did
#
# stop word: it
#
# stop word: because
#
# stop word: you
#
# stop word: the
#
# stop word: of
#
# stop word: the
#
# stop word: that
#
# stop word: For
#
# stop word: even
#
# stop word: as
#
# stop word: we
#
# stop word: we
#
# stop word: the
#
# stop word: that
#
# stop word: will
#
# stop word: are
#
# stop word: the
#
# stop word: of
#
# stop word: our
#
# stop word: two
#
# stop word: a
#
# stop word: in
#
# stop word: the
#
# stop word: in
#
# stop word: a
#
# stop word: Even
#
# stop word: as
#
# stop word: we
#
# stop word: here
#
# stop word: we
#
# stop word: there
#
# stop word: are
#
# stop word: up
#
# stop word: in
#
# stop word: the
#
# stop word: of
#
# stop word: and
#
# stop word: the
#
# stop word: of
#
# stop word: to
#
# stop word: their
#
# stop word: for
#
# stop word: us
#
# stop word: There
#
# stop word: are
#
# stop word: and
#
# stop word: who
#
# stop word: will
#
# stop word: after
#
# stop word: the
#
# stop word: and
#
# stop word: how
#
# stop word: they
#
# stop word: ’ll
#
# stop word: make
#
# stop word: the
#
# stop word: or
#
# stop word: their
#
# stop word: or
#
# stop word: enough
#
# stop word: for
#
# stop word: their
#
# stop word: ’s
#
# stop word: There
#
# stop word: ’s
#
# stop word: to
#
# stop word: to
#
# stop word: be
#
# stop word: to
#
# stop word: and
#
# stop word: to
#
# stop word: to
#
# stop word: The
#
# stop word: will
#
# stop word: be
#
# stop word: Our
#
# stop word: will
#
# stop word: be
#
# stop word: We
#
# stop word: may
#
# stop word: not
#
# stop word: get
#
# stop word: there
#
# stop word: in
#
# stop word: one
#
# stop word: or
#
# stop word: even
#
# stop word: in
#
# stop word: one
#
# stop word: But
#
# stop word: I
#
# stop word: have
#
# stop word: never
#
# stop word: been
#
# stop word: more
#
# stop word: than
#
# stop word: I
#
# stop word: am
#
# stop word: that
#
# stop word: we
#
# stop word: will
#
# stop word: get
#
# stop word: there
#
# stop word: I
#
# stop word: you
#
# stop word: we
#
# stop word: as
#
# stop word: a
#
# stop word: will
#
# stop word: get
#
# stop word: there
#
# stop word: There
#
# stop word: will
#
# stop word: be
#
# stop word: and
#
# stop word: There
#
# stop word: are
#
# stop word: many
#
# stop word: who
#
# stop word: n’t
#
# stop word: with
#
# stop word: every
#
# stop word: or
#
# stop word: I
#
# stop word: make
#
# stop word: as
#
# stop word: And
#
# stop word: we
#
# stop word: the
#
# stop word: ca
#
# stop word: n’t
#
# stop word: every
#
# stop word: But
#
# stop word: I
#
# stop word: will
#
# stop word: always
#
# stop word: be
#
# stop word: with
#
# stop word: you
#
# stop word: about
#
# stop word: the
#
# stop word: we
#
# stop word: I
#
# stop word: will
#
# stop word: to
#
# stop word: you
#
# stop word: when
#
# stop word: we
#
# stop word: And
#
# stop word: above
#
# stop word: all
#
# stop word: I
#
# stop word: will
#
# stop word: you
#
# stop word: to
#
# stop word: in
#
# stop word: the
#
# stop word: of
#
# stop word: this
#
# stop word: the
#
# stop word: only
#
# stop word: it
#
# stop word: ’s
#
# stop word: been
#
# stop word: done
#
# stop word: in
#
# stop word: for
#
# stop word: by
#
# stop word: by
#
# stop word: by
#
# stop word: What
#
# stop word: in
#
# stop word: the
#
# stop word: of
#
# stop word: can
#
# stop word: not
#
# stop word: on
#
# stop word: this
#
# stop word: This
#
# stop word: alone
#
# stop word: is
#
# stop word: not
#
# stop word: the
#
# stop word: we
#
# stop word: It
#
# stop word: is
#
# stop word: only
#
# stop word: the
#
# stop word: for
#
# stop word: us
#
# stop word: to
#
# stop word: make
#
# stop word: that
#
# stop word: And
#
# stop word: that
#
# stop word: can
#
# stop word: not
#
# stop word: if
#
# stop word: we
#
# stop word: go
#
# stop word: back
#
# stop word: to
#
# stop word: the
#
# stop word: were
#
# stop word: It
#
# stop word: ca
#
# stop word: n’t
#
# stop word: without
#
# stop word: you
#
# stop word: without
#
# stop word: a
#
# stop word: of
#
# stop word: a
#
# stop word: of
#
# stop word: So
#
# stop word: us
#
# stop word: a
#
# stop word: of
#
# stop word: of
#
# stop word: where
#
# stop word: each
#
# stop word: of
#
# stop word: us
#
# stop word: to
#
# stop word: in
#
# stop word: and
#
# stop word: and
#
# stop word: after
#
# stop word: not
#
# stop word: only
#
# stop word: ourselves
#
# stop word: but
#
# stop word: each
#
# stop word: other
#
# stop word: us
#
# stop word: that
#
# stop word: if
#
# stop word: this
#
# stop word: us
#
# stop word: anything
#
# stop word: it
#
# stop word: ’s
#
# stop word: that
#
# stop word: we
#
# stop word: can
#
# stop word: not
#
# stop word: have
#
# stop word: a
#
# stop word: while
#
# stop word: In
#
# stop word: this
#
# stop word: we
#
# stop word: or
#
# stop word: as
#
# stop word: one
#
# stop word: as
#
# stop word: one
#
# stop word: ’s
#
# stop word: the
#
# stop word: to
#
# stop word: back
#
# stop word: on
#
# stop word: the
#
# stop word: same
#
# stop word: and
#
# stop word: and
#
# stop word: that
#
# stop word: has
#
# stop word: our
#
# stop word: for
#
# stop word: so
#
# stop word: ’s
#
# stop word: that
#
# stop word: it
#
# stop word: was
#
# stop word: a
#
# stop word: from
#
# stop word: this
#
# stop word: who
#
# stop word: first
#
# stop word: the
#
# stop word: of
#
# stop word: the
#
# stop word: to
#
# stop word: the
#
# stop word: a
#
# stop word: on
#
# stop word: the
#
# stop word: of
#
# stop word: and
#
# stop word: and
#
# stop word: Those
#
# stop word: are
#
# stop word: that
#
# stop word: we
#
# stop word: all
#
# stop word: And
#
# stop word: while
#
# stop word: the
#
# stop word: has
#
# stop word: a
#
# stop word: we
#
# stop word: do
#
# stop word: so
#
# stop word: with
#
# stop word: a
#
# stop word: of
#
# stop word: and
#
# stop word: to
#
# stop word: the
#
# stop word: that
#
# stop word: have
#
# stop word: back
#
# stop word: our
#
# stop word: As
#
# stop word: to
#
# stop word: a
#
# stop word: more
#
# stop word: than
#
# stop word: ours
#
# stop word: we
#
# stop word: are
#
# stop word: not
#
# stop word: but
#
# stop word: Though
#
# stop word: may
#
# stop word: have
#
# stop word: it
#
# stop word: must
#
# stop word: not
#
# stop word: our
#
# stop word: of
#
# stop word: And
#
# stop word: to
#
# stop word: those
#
# stop word: whose
#
# stop word: I
#
# stop word: have
#
# stop word: yet
#
# stop word: to
#
# stop word: I
#
# stop word: may
#
# stop word: not
#
# stop word: have
#
# stop word: your
#
# stop word: but
#
# stop word: I
#
# stop word: your
#
# stop word: I
#
# stop word: your
#
# stop word: And
#
# stop word: I
#
# stop word: will
#
# stop word: be
#
# stop word: your
#
# stop word: too
#
# stop word: And
#
# stop word: to
#
# stop word: all
#
# stop word: those
#
# stop word: from
#
# stop word: beyond
#
# stop word: our
#
# stop word: from
#
# stop word: and
#
# stop word: to
#
# stop word: those
#
# stop word: who
#
# stop word: are
#
# stop word: around
#
# stop word: in
#
# stop word: the
#
# stop word: of
#
# stop word: the
#
# stop word: our
#
# stop word: are
#
# stop word: but
#
# stop word: our
#
# stop word: is
#
# stop word: and
#
# stop word: a
#
# stop word: of
#
# stop word: is
#
# stop word: at
#
# stop word: To
#
# stop word: those
#
# stop word: to
#
# stop word: those
#
# stop word: who
#
# stop word: would
#
# stop word: the
#
# stop word: down
#
# stop word: We
#
# stop word: will
#
# stop word: you
#
# stop word: To
#
# stop word: those
#
# stop word: who
#
# stop word: and
#
# stop word: We
#
# stop word: you
#
# stop word: And
#
# stop word: to
#
# stop word: all
#
# stop word: those
#
# stop word: who
#
# stop word: have
#
# stop word: if
#
# stop word: ’s
#
# stop word: still
#
# stop word: as
#
# stop word: we
#
# stop word: once
#
# stop word: more
#
# stop word: that
#
# stop word: the
#
# stop word: of
#
# stop word: our
#
# stop word: not
#
# stop word: from
#
# stop word: the
#
# stop word: might
#
# stop word: of
#
# stop word: our
#
# stop word: or
#
# stop word: the
#
# stop word: of
#
# stop word: our
#
# stop word: but
#
# stop word: from
#
# stop word: the
#
# stop word: of
#
# stop word: our
#
# stop word: and
#
# stop word: That
#
# stop word: ’s
#
# stop word: the
#
# stop word: of
#
# stop word: that
#
# stop word: can
#
# stop word: Our
#
# stop word: can
#
# stop word: be
#
# stop word: What
#
# stop word: we
#
# stop word: ’ve
#
# stop word: already
#
# stop word: us
#
# stop word: for
#
# stop word: what
#
# stop word: we
#
# stop word: can
#
# stop word: and
#
# stop word: must
#
# stop word: This
#
# stop word: had
#
# stop word: many
#
# stop word: and
#
# stop word: many
#
# stop word: that
#
# stop word: will
#
# stop word: be
#
# stop word: for
#
# stop word: But
#
# stop word: one
#
# stop word: that
#
# stop word: ’s
#
# stop word: on
#
# stop word: my
#
# stop word: ’s
#
# stop word: about
#
# stop word: a
#
# stop word: who
#
# stop word: her
#
# stop word: in
#
# stop word: She
#
# stop word: ’s
#
# stop word: a
#
# stop word: the
#
# stop word: of
#
# stop word: others
#
# stop word: who
#
# stop word: in
#
# stop word: to
#
# stop word: make
#
# stop word: their
#
# stop word: in
#
# stop word: this
#
# stop word: except
#
# stop word: for
#
# stop word: one
#
# stop word: is
#
# stop word: She
#
# stop word: was
#
# stop word: just
#
# stop word: a
#
# stop word: a
#
# stop word: when
#
# stop word: there
#
# stop word: were
#
# stop word: no
#
# stop word: on
#
# stop word: the
#
# stop word: or
#
# stop word: in
#
# stop word: the
#
# stop word: when
#
# stop word: someone
#
# stop word: her
#
# stop word: could
#
# stop word: n’t
#
# stop word: for
#
# stop word: two
#
# stop word: because
#
# stop word: she
#
# stop word: was
#
# stop word: a
#
# stop word: and
#
# stop word: because
#
# stop word: of
#
# stop word: the
#
# stop word: of
#
# stop word: her
#
# stop word: And
#
# stop word: I
#
# stop word: about
#
# stop word: all
#
# stop word: that
#
# stop word: she
#
# stop word: ’s
#
# stop word: throughout
#
# stop word: her
#
# stop word: in
#
# stop word: the
#
# stop word: and
#
# stop word: the
#
# stop word: the
#
# stop word: and
#
# stop word: the
#
# stop word: the
#
# stop word: we
#
# stop word: were
#
# stop word: that
#
# stop word: we
#
# stop word: ca
#
# stop word: n’t
#
# stop word: and
#
# stop word: the
#
# stop word: who
#
# stop word: on
#
# stop word: with
#
# stop word: that
#
# stop word: we
#
# stop word: can
#
# stop word: At
#
# stop word: a
#
# stop word: when
#
# stop word: ’s
#
# stop word: were
#
# stop word: and
#
# stop word: their
#
# stop word: she
#
# stop word: to
#
# stop word: see
#
# stop word: them
#
# stop word: up
#
# stop word: and
#
# stop word: out
#
# stop word: and
#
# stop word: for
#
# stop word: the
#
# stop word: we
#
# stop word: can
#
# stop word: When
#
# stop word: there
#
# stop word: was
#
# stop word: in
#
# stop word: the
#
# stop word: and
#
# stop word: across
#
# stop word: the
#
# stop word: she
#
# stop word: a
#
# stop word: itself
#
# stop word: with
#
# stop word: a
#
# stop word: a
#
# stop word: of
#
# stop word: we
#
# stop word: can
#
# stop word: When
#
# stop word: the
#
# stop word: on
#
# stop word: our
#
# stop word: and
#
# stop word: the
#
# stop word: she
#
# stop word: was
#
# stop word: there
#
# stop word: to
#
# stop word: a
#
# stop word: to
#
# stop word: and
#
# stop word: a
#
# stop word: was
#
# stop word: we
#
# stop word: can
#
# stop word: She
#
# stop word: was
#
# stop word: there
#
# stop word: for
#
# stop word: the
#
# stop word: in
#
# stop word: the
#
# stop word: in
#
# stop word: a
#
# stop word: in
#
# stop word: and
#
# stop word: a
#
# stop word: from
#
# stop word: who
#
# stop word: a
#
# stop word: that
#
# stop word: We
#
# stop word: we
#
# stop word: can
#
# stop word: A
#
# stop word: down
#
# stop word: on
#
# stop word: the
#
# stop word: a
#
# stop word: down
#
# stop word: in
#
# stop word: a
#
# stop word: was
#
# stop word: by
#
# stop word: our
#
# stop word: own
#
# stop word: and
#
# stop word: And
#
# stop word: this
#
# stop word: in
#
# stop word: this
#
# stop word: she
#
# stop word: her
#
# stop word: to
#
# stop word: a
#
# stop word: and
#
# stop word: her
#
# stop word: because
#
# stop word: after
#
# stop word: in
#
# stop word: through
#
# stop word: the
#
# stop word: of
#
# stop word: and
#
# stop word: the
#
# stop word: of
#
# stop word: she
#
# stop word: how
#
# stop word: can
#
# stop word: we
#
# stop word: can
#
# stop word: we
#
# stop word: have
#
# stop word: so
#
# stop word: We
#
# stop word: have
#
# stop word: so
#
# stop word: much
#
# stop word: But
#
# stop word: there
#
# stop word: is
#
# stop word: so
#
# stop word: much
#
# stop word: more
#
# stop word: to
#
# stop word: do
#
# stop word: So
#
# stop word: us
#
# stop word: ourselves
#
# stop word: if
#
# stop word: our
#
# stop word: should
#
# stop word: to
#
# stop word: see
#
# stop word: the
#
# stop word: next
#
# stop word: if
#
# stop word: my
#
# stop word: should
#
# stop word: be
#
# stop word: so
#
# stop word: to
#
# stop word: as
#
# stop word: as
#
# stop word: what
#
# stop word: will
#
# stop word: they
#
# stop word: see
#
# stop word: What
#
# stop word: will
#
# stop word: we
#
# stop word: have
#
# stop word: made
#
# stop word: This
#
# stop word: is
#
# stop word: our
#
# stop word: to
#
# stop word: that
#
# stop word: call
#
# stop word: This
#
# stop word: is
#
# stop word: our
#
# stop word: This
#
# stop word: is
#
# stop word: our
#
# stop word: to
#
# stop word: put
#
# stop word: our
#
# stop word: back
#
# stop word: to
#
# stop word: and
#
# stop word: of
#
# stop word: for
#
# stop word: our
#
# stop word: to
#
# stop word: and
#
# stop word: the
#
# stop word: of
#
# stop word: to
#
# stop word: the
#
# stop word: and
#
# stop word: that
#
# stop word: that
#
# stop word: out
#
# stop word: of
#
# stop word: many
#
# stop word: we
#
# stop word: are
#
# stop word: one
#
# stop word: that
#
# stop word: while
#
# stop word: we
#
# stop word: we
#
# stop word: And
#
# stop word: where
#
# stop word: we
#
# stop word: are
#
# stop word: with
#
# stop word: and
#
# stop word: and
#
# stop word: those
#
# stop word: who
#
# stop word: us
#
# stop word: that
#
# stop word: we
#
# stop word: ca
#
# stop word: n’t
#
# stop word: we
#
# stop word: will
#
# stop word: with
#
# stop word: that
#
# stop word: that
#
# stop word: up
#
# stop word: the
#
# stop word: of
#
# stop word: a
#
# stop word: we
#
# stop word: can
#
# Texto sin stop words: “ Hello , Chicago .
#  doubts America place things possible , wonders dream founders alive time , questions power democracy , tonight answer .
#  answer told lines stretched schools churches numbers nation seen , people waited hours hours , time lives , believed time different , voices difference .
#  answer spoken young old , rich poor , Democrat Republican , black , white , Hispanic , Asian , Native American , gay , straight , disabled disabled . Americans sent message world collection individuals collection red states blue states .
#  , , United States America .
#  answer led told long cynical fearful doubtful achieve hands arc history bend hope better day .
#  long time coming , tonight , date election defining moment change come America .
#  [ read ]
#
#  start money endorsements . campaign hatched halls Washington . began backyards Des Moines living rooms Concord porches Charleston . built working men women dug little savings $ 5 $ 10 $ 20 cause .
#  grew strength young people rejected myth generation apathy left homes families jobs offered little pay sleep .
#  drew strength - - young people braved bitter cold scorching heat knock doors perfect strangers , millions Americans volunteered organized proved centuries later government people , people , people perished Earth .
#  victory .
#  know win election . know .
#  understand enormity task lies ahead . celebrate tonight , know challenges tomorrow bring greatest lifetime — wars , planet peril , worst financial crisis century .
#  stand tonight , know brave Americans waking deserts Iraq mountains Afghanistan risk lives .
#  mothers fathers lie awake children fall asleep wonder mortgage pay doctors ’ bills save child college education .
#  new energy harness , new jobs created , new schools build , threats meet , alliances repair .
#  road ahead long . climb steep . year term . , America , hopeful tonight .
#  promise , people .
#  setbacks false starts . wo agree decision policy president . know government solve problem .
#  honest challenges face . listen , especially disagree . , , ask join work remaking nation , way America 221 years — block block , brick brick , calloused hand calloused hand .
#  began 21 months ago depths winter end autumn night .
#  victory change seek . chance change . happen way things .
#  happen , new spirit service , new spirit sacrifice .
#  let summon new spirit patriotism , responsibility , resolves pitch work harder look .
#  Let remember , financial crisis taught , thriving Wall Street Main Street suffers .
#  country , rise fall nation , people . Let resist temptation fall partisanship pettiness immaturity poisoned politics long .
#  Let remember man state carried banner Republican Party White House , party founded values self - reliance individual liberty national unity .
#  values share . Democratic Party won great victory tonight , measure humility determination heal divides held progress .
#  Lincoln said nation far divided , enemies friends . passion strained , break bonds affection .
#  Americans support earn , won vote tonight , hear voices . need help . president , .
#  watching tonight shores , parliaments palaces , huddled radios forgotten corners world , stories singular , destiny shared , new dawn American leadership hand .
#  — tear world : defeat . seek peace security : support . wondered America beacon burns bright : Tonight proved true strength nation comes arms scale wealth , enduring power ideals : democracy , liberty , opportunity unyielding hope .
#  true genius America : America change . union perfected . achieved gives hope achieve tomorrow .
#  election firsts stories told generations . mind tonight woman cast ballot Atlanta . lot like millions stood line voice heard election thing : Ann Nixon Cooper 106 years old .
#  born generation past slavery ; time cars road planes sky ; like vote reasons — woman color skin .
#  tonight , think seen century America — heartache hope ; struggle progress ; times told , people pressed American creed : Yes .
#  time women voices silenced hopes dismissed , lived stand speak reach ballot . Yes .
#  despair dust bowl depression land , saw nation conquer fear New Deal , new jobs , new sense common purpose . Yes .
#  bombs fell harbor tyranny threatened world , witness generation rise greatness democracy saved . Yes .
#  buses Montgomery , hoses Birmingham , bridge Selma , preacher Atlanta told people “ Shall Overcome . ” Yes .
#  man touched moon , wall came Berlin , world connected science imagination .
#  year , election , touched finger screen , cast vote , 106 years America , best times darkest hours , knows America change .
#  Yes .
#  America , come far . seen . . tonight , let ask — children live century ; daughters lucky live long Ann Nixon Cooper , change ? progress ?
#  chance answer . moment .
#  time , people work open doors opportunity kids ; restore prosperity promote cause peace ; reclaim American dream reaffirm fundamental truth , , , ; breathe , hope . met cynicism doubts tell , respond timeless creed sums spirit people : Yes , . [

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #Se utiliza un ciclo for para recorrer los tokens, posterior se utiliza la propiedad is_stop del token par avlaidar si ese es un stop word
# #en el segundo if, se valida que el token no es stop word y lo guarda en una nueva lista vacia de tokens
# #finalmente se concatena a una cadena la lsita de tokens.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 6.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué atributo del token contiene la etiqueta NER?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
#para llamar al nombre de la entidad ents.label_ y ents.text para el valor
ents = list(doc.ents)

for token in doc:
    # Verificar si el token es parte de una entidad nombrada
    if token.ent_type_: # and token.ent_type_ == "PERSON": #imprimir por token entidad PERSON
        print("Token:", token.text)
        print("Etiqueta NER:", token.ent_type_)
print("________________________________________________________________")

for token in ents:
    print("Token ents:", token.text)
    print("Etiqueta ents NER:", token.label_)
# Out:
# Token: Chicago
# Etiqueta NER: GPE
# Token: America
# Etiqueta NER: GPE
# Token: tonight
# Etiqueta NER: TIME
# Token: three
# Etiqueta NER: TIME
# Token: hours
# Etiqueta NER: TIME
# Token: four
# Etiqueta NER: TIME
# Token: hours
# Etiqueta NER: TIME
# Token: first
# Etiqueta NER: ORDINAL
# Token: Democrat
# Etiqueta NER: NORP
# Token: Republican
# Etiqueta NER: NORP
# Token: Hispanic
# Etiqueta NER: NORP
# Token: Asian
# Etiqueta NER: NORP
# Token: Native
# Etiqueta NER: NORP
# Token: American
# Etiqueta NER: NORP
# Token: Americans
# Etiqueta NER: NORP
# Token: the
# Etiqueta NER: GPE
# Token: United
# Etiqueta NER: GPE
# Token: States
# Etiqueta NER: GPE
# Token: of
# Etiqueta NER: GPE
# Token: America
# Etiqueta NER: GPE
# Token: tonight
# Etiqueta NER: TIME
# Token: America
# Etiqueta NER: GPE
# Token: Washington
# Etiqueta NER: GPE
# Token: Des
# Etiqueta NER: GPE
# Token: Moines
# Etiqueta NER: GPE
# Token: Concord
# Etiqueta NER: GPE
# Token: Charleston
# Etiqueta NER: GPE
# Token: $
# Etiqueta NER: MONEY
# Token: 5
# Etiqueta NER: MONEY
# Token: and
# Etiqueta NER: MONEY
# Token: $
# Etiqueta NER: MONEY
# Token: 10
# Etiqueta NER: MONEY
# Token: and
# Etiqueta NER: MONEY
# Token: $
# Etiqueta NER: MONEY
# Token: 20
# Etiqueta NER: MONEY
# Token: millions
# Etiqueta NER: CARDINAL
# Token: Americans
# Etiqueta NER: NORP
# Token: more
# Etiqueta NER: DATE
# Token: than
# Etiqueta NER: DATE
# Token: two
# Etiqueta NER: DATE
# Token: centuries
# Etiqueta NER: DATE
# Token: later
# Etiqueta NER: DATE
# Token: Earth
# Etiqueta NER: LOC
# Token: tonight
# Etiqueta NER: TIME
# Token: tomorrow
# Etiqueta NER: DATE
# Token: two
# Etiqueta NER: CARDINAL
# Token: a
# Etiqueta NER: DATE
# Token: century
# Etiqueta NER: DATE
# Token: tonight
# Etiqueta NER: TIME
# Token: Americans
# Etiqueta NER: NORP
# Token: Iraq
# Etiqueta NER: GPE
# Token: Afghanistan
# Etiqueta NER: GPE
# Token: one
# Etiqueta NER: DATE
# Token: year
# Etiqueta NER: DATE
# Token: one
# Etiqueta NER: CARDINAL
# Token: America
# Etiqueta NER: GPE
# Token: tonight
# Etiqueta NER: TIME
# Token: America
# Etiqueta NER: GPE
# Token: 221
# Etiqueta NER: DATE
# Token: years
# Etiqueta NER: DATE
# Token: 21
# Etiqueta NER: DATE
# Token: months
# Etiqueta NER: DATE
# Token: ago
# Etiqueta NER: DATE
# Token: winter
# Etiqueta NER: DATE
# Token: this
# Etiqueta NER: TIME
# Token: autumn
# Etiqueta NER: TIME
# Token: night
# Etiqueta NER: TIME
# Token: Main
# Etiqueta NER: FAC
# Token: Street
# Etiqueta NER: FAC
# Token: one
# Etiqueta NER: CARDINAL
# Token: one
# Etiqueta NER: CARDINAL
# Token: first
# Etiqueta NER: ORDINAL
# Token: the
# Etiqueta NER: ORG
# Token: Republican
# Etiqueta NER: ORG
# Token: Party
# Etiqueta NER: ORG
# Token: the
# Etiqueta NER: ORG
# Token: White
# Etiqueta NER: ORG
# Token: House
# Etiqueta NER: ORG
# Token: the
# Etiqueta NER: ORG
# Token: Democratic
# Etiqueta NER: ORG
# Token: Party
# Etiqueta NER: ORG
# Token: tonight
# Etiqueta NER: TIME
# Token: Lincoln
# Etiqueta NER: ORG
# Token: Americans
# Etiqueta NER: NORP
# Token: tonight
# Etiqueta NER: TIME
# Token: tonight
# Etiqueta NER: TIME
# Token: American
# Etiqueta NER: NORP
# Token: America
# Etiqueta NER: GPE
# Token: Tonight
# Etiqueta NER: TIME
# Token: America
# Etiqueta NER: GPE
# Token: America
# Etiqueta NER: GPE
# Token: tomorrow
# Etiqueta NER: DATE
# Token: tonight
# Etiqueta NER: TIME
# Token: Atlanta
# Etiqueta NER: GPE
# Token: millions
# Etiqueta NER: CARDINAL
# Token: one
# Etiqueta NER: CARDINAL
# Token: Ann
# Etiqueta NER: PERSON
# Token: Nixon
# Etiqueta NER: PERSON
# Token: Cooper
# Etiqueta NER: PERSON
# Token: 106
# Etiqueta NER: DATE
# Token: years
# Etiqueta NER: DATE
# Token: old
# Etiqueta NER: DATE
# Token: two
# Etiqueta NER: CARDINAL
# Token: tonight
# Etiqueta NER: TIME
# Token: America
# Etiqueta NER: GPE
# Token: American
# Etiqueta NER: NORP
# Token: Montgomery
# Etiqueta NER: ORG
# Token: Birmingham
# Etiqueta NER: GPE
# Token: Selma
# Etiqueta NER: GPE
# Token: Atlanta
# Etiqueta NER: GPE
# Token: the
# Etiqueta NER: LOC
# Token: moon
# Etiqueta NER: LOC
# Token: Berlin
# Etiqueta NER: GPE
# Token: this
# Etiqueta NER: DATE
# Token: year
# Etiqueta NER: DATE
# Token: 106
# Etiqueta NER: DATE
# Token: years
# Etiqueta NER: DATE
# Token: America
# Etiqueta NER: GPE
# Token: hours
# Etiqueta NER: TIME
# Token: America
# Etiqueta NER: GPE
# Token: America
# Etiqueta NER: GPE
# Token: tonight
# Etiqueta NER: TIME
# Token: the
# Etiqueta NER: DATE
# Token: next
# Etiqueta NER: DATE
# Token: century
# Etiqueta NER: DATE
# Token: Ann
# Etiqueta NER: PERSON
# Token: Nixon
# Etiqueta NER: PERSON
# Token: Cooper
# Etiqueta NER: PERSON
# Token: American
# Etiqueta NER: NORP
# ________________________________________________________________
# Token ents: Chicago
# Etiqueta ents NER: GPE
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: three hours
# Etiqueta ents NER: TIME
# Token ents: four hours
# Etiqueta ents NER: TIME
# Token ents: first
# Etiqueta ents NER: ORDINAL
# Token ents: Democrat
# Etiqueta ents NER: NORP
# Token ents: Republican
# Etiqueta ents NER: NORP
# Token ents: Hispanic
# Etiqueta ents NER: NORP
# Token ents: Asian
# Etiqueta ents NER: NORP
# Token ents: Native American
# Etiqueta ents NER: NORP
# Token ents: Americans
# Etiqueta ents NER: NORP
# Token ents: the United States of America
# Etiqueta ents NER: GPE
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: Washington
# Etiqueta ents NER: GPE
# Token ents: Des Moines
# Etiqueta ents NER: GPE
# Token ents: Concord
# Etiqueta ents NER: GPE
# Token ents: Charleston
# Etiqueta ents NER: GPE
# Token ents: $5 and $10 and $20
# Etiqueta ents NER: MONEY
# Token ents: millions
# Etiqueta ents NER: CARDINAL
# Token ents: Americans
# Etiqueta ents NER: NORP
# Token ents: more than two centuries later
# Etiqueta ents NER: DATE
# Token ents: Earth
# Etiqueta ents NER: LOC
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: tomorrow
# Etiqueta ents NER: DATE
# Token ents: two
# Etiqueta ents NER: CARDINAL
# Token ents: a century
# Etiqueta ents NER: DATE
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: Americans
# Etiqueta ents NER: NORP
# Token ents: Iraq
# Etiqueta ents NER: GPE
# Token ents: Afghanistan
# Etiqueta ents NER: GPE
# Token ents: one year
# Etiqueta ents NER: DATE
# Token ents: one
# Etiqueta ents NER: CARDINAL
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: 221 years
# Etiqueta ents NER: DATE
# Token ents: 21 months ago
# Etiqueta ents NER: DATE
# Token ents: winter
# Etiqueta ents NER: DATE
# Token ents: this autumn night
# Etiqueta ents NER: TIME
# Token ents: Main Street
# Etiqueta ents NER: FAC
# Token ents: one
# Etiqueta ents NER: CARDINAL
# Token ents: one
# Etiqueta ents NER: CARDINAL
# Token ents: first
# Etiqueta ents NER: ORDINAL
# Token ents: the Republican Party
# Etiqueta ents NER: ORG
# Token ents: the White House
# Etiqueta ents NER: ORG
# Token ents: the Democratic Party
# Etiqueta ents NER: ORG
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: Lincoln
# Etiqueta ents NER: ORG
# Token ents: Americans
# Etiqueta ents NER: NORP
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: American
# Etiqueta ents NER: NORP
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: Tonight
# Etiqueta ents NER: TIME
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: tomorrow
# Etiqueta ents NER: DATE
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: Atlanta
# Etiqueta ents NER: GPE
# Token ents: millions
# Etiqueta ents NER: CARDINAL
# Token ents: one
# Etiqueta ents NER: CARDINAL
# Token ents: Ann Nixon Cooper
# Etiqueta ents NER: PERSON
# Token ents: 106 years old
# Etiqueta ents NER: DATE
# Token ents: two
# Etiqueta ents NER: CARDINAL
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: American
# Etiqueta ents NER: NORP
# Token ents: Montgomery
# Etiqueta ents NER: ORG
# Token ents: Birmingham
# Etiqueta ents NER: GPE
# Token ents: Selma
# Etiqueta ents NER: GPE
# Token ents: Atlanta
# Etiqueta ents NER: GPE
# Token ents: the moon
# Etiqueta ents NER: LOC
# Token ents: Berlin
# Etiqueta ents NER: GPE
# Token ents: this year
# Etiqueta ents NER: DATE
# Token ents: 106 years
# Etiqueta ents NER: DATE
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: hours
# Etiqueta ents NER: TIME
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: America
# Etiqueta ents NER: GPE
# Token ents: tonight
# Etiqueta ents NER: TIME
# Token ents: the next century
# Etiqueta ents NER: DATE
# Token ents: Ann Nixon Cooper
# Etiqueta ents NER: PERSON
# Token ents: American
# Etiqueta ents NER: NORP

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #para validar que atributo dle token contiene etiqueta NER, se dispone de 2 variantes
# #primera es procesar con el token, donde la propiedad ent_type_(nombre entidad), ent_type(objeto de tipo entidad),permite extraer la etiqueta.
# #la alternativa es directamente tomar al doc y con la pripeidad ents, permite extraer las etiquetas NER.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 7.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades nombradas soporta Spacy?, ¿Qué significa cada una?</span>
#
# <b>Nota</b>: Debes escribir el código que liste las entidades disponibles y la explicación de las mismas. El listado sin código se considerará respuesta incompleta.

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
nueva_lista_entidades = []
# Crear un conjunto para almacenar las etiquetas NER sin repetir
etiquetas_sin_repetidos = set()
for token in doc:
    # Verificar si el token es parte de una entidad nombrada
    if token.ent_type_:
        nueva_lista_entidades.append(token.ent_type_)
        etiquetas_sin_repetidos.add(token.ent_type_)
        
# Convertir el conjunto a una lista
lista_etiquetas_sin_repetidos = list(etiquetas_sin_repetidos)

print("lista:",lista_etiquetas_sin_repetidos)
print("objeto tipo lista:",set(nueva_lista_entidades))
# Out:
# lista: ['DATE', 'ORG', 'TIME', 'CARDINAL', 'PERSON', 'NORP', 'GPE', 'LOC', 'ORDINAL', 'FAC', 'MONEY']
# objeto tipo lista: {'DATE', 'ORG', 'TIME', 'CARDINAL', 'PERSON', 'NORP', 'GPE', 'LOC', 'ORDINAL', 'FAC', 'MONEY'}

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #existen 2 enfoques para obtener la entidad de los tokens y posterior aplciar un filtro de no repetidos
# #primero, al validar si el token es entidad, se añade a un conjunto set(), donde elimina repetidos y posterior se transforma a una lista
# #segundo, al valodar si el token es entidad, se añade el token valido a un neuvmo token y fnalmente se aplica el set, para eliminar repetidos.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 8.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades nombradas diferentes son reconocidas en el texto?, ¿cuántas hay de cada tipo?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
#Para su solucion se dispone de 2 casos
#caso 1
entidades_por_tipo = {}
for entidad in doc.ents:
    # Obtener el tipo de la entidad nombrada
    tipo_entidad = entidad.label_
    
    # Actualizar el recuento para este tipo de entidad nombrada
    if tipo_entidad in entidades_por_tipo:
        entidades_por_tipo[tipo_entidad] += 1
    else:
        entidades_por_tipo[tipo_entidad] = 1

print("Entidades encontradas y su cantidad:")
for tipo_entidad, recuento in entidades_por_tipo.items():
    print(tipo_entidad, ":", recuento)
#caso 2

from collections import Counter      

nueva_lista_entidades = []
for token in doc:
    # Verificar si el token es parte de una entidad nombrada
    if token.ent_type_:
        nueva_lista_entidades.append(token.ent_type_)
        
frecuencia_entidades = Counter(nueva_lista_entidades)
for valor, frecuencia in frecuencia_entidades.items():
    print(f"El valor '{valor}' aparece {frecuencia} veces.")
# Out:
# Entidades encontradas y su cantidad:
# GPE : 24
# TIME : 16
# ORDINAL : 2
# NORP : 12
# MONEY : 1
# CARDINAL : 8
# DATE : 12
# LOC : 2
# FAC : 1
# ORG : 5
# PERSON : 2
# El valor 'GPE' aparece 29 veces.
# El valor 'TIME' aparece 20 veces.
# El valor 'ORDINAL' aparece 2 veces.
# El valor 'NORP' aparece 13 veces.
# El valor 'MONEY' aparece 8 veces.
# El valor 'CARDINAL' aparece 8 veces.
# El valor 'DATE' aparece 27 veces.
# El valor 'LOC' aparece 3 veces.
# El valor 'FAC' aparece 2 veces.
# El valor 'ORG' aparece 11 veces.
# El valor 'PERSON' aparece 6 veces.

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# #caso 1, accediendo directametne a ents y obteniendo la propiedad, se valida si la entidad esta en entidades_por_tipo, si no esta se inicializa con 1
# #si esta, se incrementa el conto y se añade como propiedad esa entidad.
# #para la trabajar con ents, se no se extrae por tokens sino por entidad.
# #caso 2, recorre el token individual, se valida si es entidad y se crea una lsita completa.
# #se utiliza Counter para obtener la frecuencia de cada valor de la lista y posteior se imprime.
# #tomar en cuenta que la diferenecia entre la primera es que al extraer la entidad por token un nombre Ann Nixon Cooper, lo va a tomar token por token.
# #caso de ents, tomara todo el nombre que representa al PERSON {Ann Nixon Cooper}

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 9.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Explica con tus palabras qué es el código IOB para el reconocimiento de entiedades. Pon un ejemplo, sacado del texto, de una etiqueta de un único token y una etiqueta compuesta por varios tokens.</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
#se toma una oracion de la poscion 6 de la lsita de oraciones
doc_1 = nlp("And I know you didn’t do this just to win an election. And I know you didn’t do it for me.")
for token in doc_1:
    # Imprimir el texto del token y su etiqueta IOB
    print(token.text, token.ent_iob_)
print()
doc_2 = nlp("ecuador")
for token in doc_2:
    print(token.text, token.ent_iob_)
# Out:
# And O
# I O
# know O
# you O
# did O
# n’t O
# do O
# this O
# just O
# to O
# win O
# an O
# election O
# . O
# And O
# I O
# know O
# you O
# did O
# n’t O
# do O
# it O
# for O
# me O
# . O
#
# ecuador B

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>#Es un etiquetado de una secuencia de palabras de un texto de entrada, para reconocer entidades que pertenesca cada uno de estos.
# #B -> indica palabra que inicia en una entidad.
# #I-> que la apalabra esta dentro de la entidad.
# #O -> esta fuera de una entidad nomrbada.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 10.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué POS Tags aparecen en el texto, y cuántos hay tokens hay de cada uno?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
pos_tags_count = {}

for token in doc:
    # Obtener la etiqueta POS del token diferencias pos_(extrae el nombre), pos(extrae el objeto pos) para obtener propiedades léxicas y gramaticales adicionales de las palabras
    #la libreria de spacy utiliza los pos tags universales definidos pro https://universaldependencies.org/u/pos/ 
    pos_tag = token.pos_
    
    # Actualizar el recuento para esta etiqueta POS
    if pos_tag in pos_tags_count:
        pos_tags_count[pos_tag] += 1
    else:
        pos_tags_count[pos_tag] = 1

print("etiquetas POS:")
for pos_tag, count in pos_tags_count.items():
    print(pos_tag, ":", count)
# Out:
# etiquetas POS:
# PUNCT : 205
# PROPN : 56
# SPACE : 46
# SCONJ : 51
# PRON : 243
# VERB : 211
# ADV : 63
# AUX : 125
# DET : 153
# NOUN : 330
# ADJ : 93
# ADP : 189
# CCONJ : 92
# NUM : 18
# PART : 53
# SYM : 3
# INTJ : 7
# X : 1

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>#se itera el texto en tokens y se crea una lista de objetos con los pos tags y va contanto si existe ya en la lista de objetos o lo añade.
